# %%
import itertools

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy import linalg

from sklearn import mixture

import pandas as pd

import random

from sklearn.mixture import BayesianGaussianMixture

# %%
V = pd.read_csv("~/Desktop/VI submission/code/outputs/V_BRCA1.csv", index_col=0)

# %%
V
# Out:
#              V1        V2        V3        V4        V5        V6
# 1     -0.054124 -0.488133  0.058399 -0.728498 -0.456793  0.126555
# 2     -0.167012 -0.310767  0.442557  0.804061  0.130171 -0.127339
# 3      0.516360  0.065164 -0.558184  0.174432 -0.562550 -0.265832
# 4      0.658521  0.057430 -0.085168 -0.377937 -0.503320  0.399537
# 5      0.466596  0.026880 -0.275069 -0.167371 -0.496955  0.656449
# ...         ...       ...       ...       ...       ...       ...
# 24280 -0.289027  0.764671  0.123418  0.207288  0.522181 -0.029467
# 24281 -0.427699  0.574341  0.457646 -0.307016  0.395815 -0.163818
# 24282 -0.234098  0.308979  0.256803 -0.175017 -0.825370  0.268172
# 24283 -0.477567  0.623752  0.258768  0.238846  0.461201 -0.214822
# 24284  0.000842  0.696589  0.157210  0.314737 -0.611028 -0.132789
#
# [24284 rows x 6 columns]

# %%
V = V.to_numpy()

# %%
K = [14]
weightP = [1/14]

# %%
ddgmmLabel=[]
ddgmm_prob = []
for k in K:
  for w in weightP:
    dpgmm = mixture.BayesianGaussianMixture(
        n_components = k,
        covariance_type="full",
        weight_concentration_prior= w,
        weight_concentration_prior_type="dirichlet_distribution",
        mean_precision_prior=1e-2,
        covariance_prior=1e0 * np.eye(6),
        init_params="kmeans",
        max_iter=200,
        random_state=2,
    ).fit(V)

  ddgmmLabel.append(dpgmm.predict(V))
  ddgmm_prob.append(dpgmm.predict_proba(V))

# %%
ddgmm_prob[0].shape
# Out:
# (24284, 6)

# %%
ddgmmLabel[0].shape
# Out:
# (24284,)

# %%
dfProb = pd.DataFrame(ddgmm_prob[0])
dfProb.to_csv('~/Desktop/VI submission/code/outputs/probs_BRCA_k8.csv', index=False)
